# %%
import eodal
import geopandas as gpd
import os

import matplotlib.pyplot as plt


from datetime import datetime
from eodal.config import get_settings
from eodal.core.scene import SceneCollection
from eodal.core.sensors.sentinel2 import Sentinel2
from eodal.mapper.feature import Feature
from eodal.mapper.filter import Filter
from eodal.mapper.mapper import Mapper, MapperConfigs

from pathlib import Path
from typing import List

# %%
Settings = get_settings()
Settings.USE_STAC = True

# %%
def preprocess_sentinel2_scenes(
    ds: Sentinel2,
    target_resolution: int,
) -> Sentinel2:
    """
    Resample Sentinel-2 scenes and mask clouds, shadows, and snow
    based on the Scene Classification Layer (SCL).

    NOTE:
        Depending on your needs, the pre-processing function can be
        fully customized using the full power of EOdal and its
        interfacing libraries!

    :param target_resolution:
        spatial target resolution to resample all bands to.
    :returns:
        resampled, cloud-masked Sentinel-2 scene.
    """
    # resample scene
    ds.resample(inplace=True, target_resolution=target_resolution)
    # mask clouds, shadows, and snow
    ds.mask_clouds_and_shadows(inplace=True)
    return ds

def get_sentinel2_scene(
    collection: str,
    time_start: datetime,
    time_end: datetime,
    geom: Path,
    cloud_pixel_percentage: int = 10
) -> SceneCollection:
    # ------------------------- Metadata Filters ---------------------------
    metadata_filters: List[Filter] = [
        Filter('cloudy_pixel_percentage','<', cloud_pixel_percentage),
        Filter('processing_level', '==', 'Level-2A')
    ]

    #%% query the scenes available (no I/O of scenes, this only fetches metadata)
    feature = Feature.from_geoseries(gpd.read_file(geom).dissolve().geometry)

    mapper_configs = MapperConfigs(
        collection=collection,
        time_start=time_start,
        time_end=time_end,
        feature=feature,
        metadata_filters=metadata_filters
    )

    mapper_configs.to_yaml('temp/sample_mapper_call.yaml')
    mapper = Mapper(mapper_configs)
    mapper.query_scenes()
    mapper.data

    scene_kwargs = {
        'scene_constructor': Sentinel2.from_safe,
        'scene_constructor_kwargs': {},
        'scene_modifier': preprocess_sentinel2_scenes,
        'scene_modifier_kwargs': {'target_resolution': 10}
    }

    mapper.load_scenes(scene_kwargs=scene_kwargs)

    return mapper.data

# %%
collection: str = 'sentinel2-msi'
time_start: datetime = datetime(2022,6,1)  # year, month, day (incl.)
time_end: datetime = datetime(2022,6,30)   # year, month, day (incl.)
geom: Path = '../images/bounding_box/bounding_box_eth_centrum_eschikon.geojson'

scenes = get_sentinel2_scene(collection, time_start, time_end, geom)
scenes.plot(band_selection=['red'], figsize=(60,20))
# Out:
# 2023-03-22 11:29:51,358 eodal        INFO     Starting extraction of sentinel2 scenes

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Julia\Desktop\thesis\remote_sensing\preprocess_images\sentinel_2.ipynb Cell 5 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Julia/Desktop/thesis/remote_sensing/preprocess_images/sentinel_2.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> for x in scenes:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Julia/Desktop/thesis/remote_sensing/preprocess_images/sentinel_2.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a>     print(x[1].get_values(['red'][0]).shape)
#
# File c:\Users\Julia\AppData\Local\Programs\Python\Python310\lib\site-packages\eodal\utils\decorators.py:160, in check_band_names.<locals>.wrapper(self, *args, **kwargs)
#     157         if not set(band_names).issubset(self.band_names):
#     158             raise BandNotFoundError(f"{band_names} not found in collection")
# --> 160 return f(self, *args, **kwargs)
#
# File c:\Users\Julia\AppData\Local\Programs\Python\Python310\lib\site-packages\eodal\core\raster.py:1212, in RasterCollection.get_values(self, band_selection)
#    1208     band_selection = self.band_names
#    1210 # check if the selected bands have the same spatial extent, pixel
#    1211 # cell size and spatial coordinate system (if not stacking fails)
# -> 1212 if not self.is_bandstack(band_selection):
#    1213     raise ValueError(
#    1214         "Cannot stack raster bands - they do not align spatially "
#    1215         "to each other.\nConsider reprojection/ resampling first."
#    1216     )
#    1218 stack_bands = [self.get_band(x).values for x in band_selection]
#
# File c:\Users\Julia\AppData\Local\Programs\Python\Python310\lib\site-packages\eodal\core\raster.py:907, in RasterCollection.is_bandstack(self, band_selection)
#     903     return None
#     905 # otherwise use the first band (that will then always exist)
#     906 # as reference to check the other bands (if any) against
# --> 907 first_geo_info = self[band_selection[0]].geo_info
#     908 first_shape = (self[band_selection[0]].nrows, self[band_selection[0]].ncols)
#     909 for idx in range(1, len(band_selection)):
#
# File c:\Users\Julia\AppData\Local\Programs\Python\Python310\lib\site-packages\eodal\core\raster.py:435, in RasterCollection.__getitem__(self, key)
#     433 if isinstance(key, str):
#     434     try:
# --> 435         return _get_band_from_key(key=key)
#     436     except IndexError:
#     437         raise BandNotFoundError(f'Could not find band {key}')
#
# File c:\Users\Julia\AppData\Local\Programs\Python\Python310\lib\site-packages\eodal\core\raster.py:430, in RasterCollection.__getitem__.<locals>._get_band_from_key(key)
#     428         band_idx = self.band_aliases.index(key)
#     429         key = self.band_names[band_idx]
# --> 430 return self.collection[key]
#
# KeyError: 'B'

# %%
# set environment variable to enable working with STAC from Planetary Computer
# !set USE_STAC=True

# %%
# define a function for Sentinel-2 data extraction from the archive
import numpy as np
import matplotlib as plt

from datetime import datetime
from typing import Any, Dict

from eodal.core.scene import SceneCollection
from eodal.core.sensors.sentinel2 import Sentinel2
from eodal.mapper.feature import Feature
from eodal.mapper.filter import Filter
from eodal.mapper.mapper import Mapper,MapperConfigs

from shapely.geometry import MultiPoint, MultiPolygon, Point, Polygon

def preprocess_sentinel2_scenes(
    ds: Sentinel2,
    target_resolution: int,
) -> Sentinel2:
    """
    Resample Sentinel-2 scenes and mask clouds, shadows, and snow
    based on the Scene Classification Layer (SCL).

    NOTE:
        Depending on your needs, the pre-processing function can be
        fully customized using the full power of EOdal and its
    interfacing libraries!

    :param target_resolution:
        spatial target resolution to resample all bands to.
    :returns:
        resampled, cloud-masked Sentinel-2 scene.
    """
    # resample scene
    ds.resample(inplace=True, target_resolution=target_resolution)
    # mask clouds, shadows, and snow
    ds.mask_clouds_and_shadows(inplace=True, cloud_classes=[3, 8, 9, 10, 11])
    return ds

def get_s2_data(
        time_start: datetime,
        time_end: datetime,
        scene_cloud_cover_threshold: float = 80,
        feature_cloud_cover_threshold: float = 50,
        spatial_resolution: int = 10
) -> SceneCollection:
    metadata_filters = [
        Filter('cloudy_pixel_percentage','<', scene_cloud_cover_threshold),
        Filter('processing_level', '==', 'Level-2A')
    ]

    # feature = Feature('zurich', Point([12991, 5267205]), epsg = 32633)
    feature = Feature('test', Polygon(shell=((13001, 5267205), (12991, 5267305), (12891, 5267205), (12991, 5267105))), epsg=32633)

    mapper_configs = MapperConfigs(
        collection='sentinel2-msi',
        time_start=time_start,
        time_end=time_end,
        feature=feature,
        metadata_filters=metadata_filters
    )

    mapper = Mapper(mapper_configs)

    mapper.query_scenes()

    scene_kwargs = {
        'scene_constructor': Sentinel2.from_safe,            # this tells the mapper how to read and load the data (i.e., Sentinel-2 scenes)
        'scene_constructor_kwargs': {},                      # here you could specify which bands to read
        'scene_modifier': preprocess_sentinel2_scenes,       # this tells the mapper about (optional) pre-processing of the loaded scenes (must be a callable)
        'scene_modifier_kwargs': {'target_resolution': 10}   # here, you have to specify the value of the arguments the `scene_modifier` requires
    }
    mapper.load_scenes(scene_kwargs=scene_kwargs)

    scenes_to_del = []
    mapper.metadata['scene_used'] = 'yes'
    for scene_id, scene in mapper.data:

        # check if scene is blackfilled (nodata); if yes continue
        if scene.is_blackfilled:
            scenes_to_del.append(scene_id)
            mapper.metadata.loc[mapper.metadata.sensing_time.dt.strftime('%Y-%m-%d %H:%M') == scene_id.strftime('%Y-%m-%d %H:%M')[0:16], 'scene_used'] = 'No [blackfill]'
            continue

        # check cloud coverage (including shadows and snow) of the field parcel
        feature_cloud_cover = scene.get_cloudy_pixel_percentage(cloud_classes=[3, 8, 9, 10, 11])

        # if the scene is too cloudy, we skip it
        if feature_cloud_cover > feature_cloud_cover_threshold:
            scenes_to_del.append(scene_id)
            mapper.metadata.loc[mapper.metadata.sensing_time.dt.strftime('%Y-%m-%d %H:%M') == scene_id.strftime('%Y-%m-%d %H:%M')[0:16], 'scene_used'] = 'No [clouds]'
            continue

        # calculate the NDVI and MSAVI
        scene.calc_si('NDVI', inplace=True)
        scene.calc_si('MSAVI', inplace=True)

    # delete scenes too cloudy or containing only no-data
    for scene_id in scenes_to_del:
        del mapper.data[scene_id]
    
    return mapper

# %%
# plot parcel and its temporal development
def plot_scenes(res: SceneCollection) -> None:
    f, axes = plt.subplots(ncols=len(res), nrows=3, figsize=(26,14))
    idx = 0
    for scene_id, scene in res:
        scene.plot_multiple_bands(
            band_selection=['nir_1', 'red' ,'green'],
            ax=axes[0,idx]
        )
        axes[0,idx].set_title(scene_id)
        axes[0,idx].set_xlabel('')
        axes[0,idx].get_xaxis().set_ticks([])
         # plot the MSAVI
        scene.plot_band(
            'MSAVI',
            colormap='summer',
            colorbar_label='MSAVI [-]',
            vmin=0,
            vmax=0.8,
            ax=axes[1,idx]
        )
        # plot the MSAVI
        scene.plot_band(
            'NDVI',
            colormap='summer',
            colorbar_label='NDVI [-]',
            vmin=0,
            vmax=1.,
            ax=axes[2,idx]
        )
        # set y and x ticks as well as title strings at the outer bounds, only, of to improve readability
        if idx > 0:
            for jdx in range(3):
                axes[jdx,idx].get_yaxis().set_ticks([])
                axes[jdx,idx].set_ylabel('')
        for jdx in range(1,3):
            for tdx in range(len(res)):
                axes[jdx,tdx].set_title('')
                if jdx == 1:
                    axes[jdx,tdx].get_xaxis().set_ticks([])
                    axes[jdx,tdx].set_xlabel('')
        idx += 1

# %%
data = get_s2_data(datetime(2022,1,1), datetime(2022,10,1))
# Out:
# 2023-03-20 15:09:54,584 eodal        INFO     Starting extraction of sentinel2 scenes
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Julia\Desktop\thesis\remote_sensing\preprocess_images\sentinel_2.ipynb Cell 9 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Julia/Desktop/thesis/remote_sensing/preprocess_images/sentinel_2.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> data = get_s2_data(datetime(2022,1,1), datetime(2022,10,1))
#
# c:\Users\Julia\Desktop\thesis\remote_sensing\preprocess_images\sentinel_2.ipynb Cell 9 in 7
#      <a href='vscode-notebook-cell:/c%3A/Users/Julia/Desktop/thesis/remote_sensing/preprocess_images/sentinel_2.ipynb#X13sZmlsZQ%3D%3D?line=64'>65</a> mapper.query_scenes()
#      <a href='vscode-notebook-cell:/c%3A/Users/Julia/Desktop/thesis/remote_sensing/preprocess_images/sentinel_2.ipynb#X13sZmlsZQ%3D%3D?line=66'>67</a> scene_kwargs = {
#      <a href='vscode-notebook-cell:/c%3A/Users/Julia/Desktop/thesis/remote_sensing/preprocess_images/sentinel_2.ipynb#X13sZmlsZQ%3D%3D?line=67'>68</a>     'scene_constructor': Sentinel2.from_safe,            # this tells the mapper how to read and load the data (i.e., Sentinel-2 scenes)
#      <a href='vscode-notebook-cell:/c%3A/Users/Julia/Desktop/thesis/remote_sensing/preprocess_images/sentinel_2.ipynb#X13sZmlsZQ%3D%3D?line=68'>69</a>     'scene_constructor_kwargs': {},                      # here you could specify which bands to read
#      <a href='vscode-notebook-cell:/c%3A/Users/Julia/Desktop/thesis/remote_sensing/preprocess_images/sentinel_2.ipynb#X13sZmlsZQ%3D%3D?line=69'>70</a>     'scene_modifier': preprocess_sentinel2_scenes,       # this tells the mapper about (optional) pre-processing of the loaded scenes (must be a callable)
#      <a href='vscode-notebook-cell:/c%3A/Users/Julia/Desktop/thesis/remote_sensing/preprocess_images/sentinel_2.ipynb#X13sZmlsZQ%3D%3D?line=70'>71</a>     'scene_modifier_kwargs': {'target_resolution': 10}   # here, you have to specify the value of the arguments the `scene_modifier` requires
#      <a href='vscode-notebook-cell:/c%3A/Users/Julia/Desktop/thesis/remote_sensing/preprocess_images/sentinel_2.ipynb#X13sZmlsZQ%3D%3D?line=71'>72</a> }
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Julia/Desktop/thesis/remote_sensing/preprocess_images/sentinel_2.ipynb#X13sZmlsZQ%3D%3D?line=72'>73</a> mapper.load_scenes(scene_kwargs=scene_kwargs)
#      <a href='vscode-notebook-cell:/c%3A/Users/Julia/Desktop/thesis/remote_sensing/preprocess_images/sentinel_2.ipynb#X13sZmlsZQ%3D%3D?line=74'>75</a> scenes_to_del = []
#      <a href='vscode-notebook-cell:/c%3A/Users/Julia/Desktop/thesis/remote_sensing/preprocess_images/sentinel_2.ipynb#X13sZmlsZQ%3D%3D?line=75'>76</a> mapper.metadata['scene_used'] = 'yes'
#
# File c:\Users\Julia\AppData\Local\Programs\Python\Python310\lib\site-packages\eodal\mapper\mapper.py:676, in Mapper.load_scenes(self, scene_kwargs, pixel_kwargs)
#     674     self._load_pixels(**pixel_kwargs)
#     675 else:
# --> 676     self._load_scenes_collection(**scene_kwargs)
#
# File c:\Users\Julia\AppData\Local\Programs\Python\Python310\lib\site-packages\eodal\mapper\mapper.py:542, in Mapper._load_scenes_collection(self, reprojection_method, scene_constructor, scene_constructor_kwargs, scene_modifier, scene_modifier_kwargs)
#     540 if not _metadata_unique.empty:
#     541     for _, item in _metadata_unique.iterrows():
# --> 542         scene = self._process_scene(
#     543             item=item,
#     544             scene_constructor=scene_constructor,
#     545             scene_constructor_kwargs=scene_constructor_kwargs,
#     546             scene_modifier=scene_modifier,
#     547             scene_modifier_kwargs=scene_modifier_kwargs,
#     548             reprojection_method=reprojection_method
#     549         )
#     550         # because ESA has some mess with the naming of their file names and
#     551         # metadata, there might be duplicated seems not detected by the mapper
#     552         # since the time stamps slightly differ (few seconds in some cases) but
#     553         # their IDs are the same
#     554         try:
#
# File c:\Users\Julia\AppData\Local\Programs\Python\Python310\lib\site-packages\eodal\mapper\mapper.py:393, in Mapper._process_scene(self, item, scene_constructor, scene_constructor_kwargs, scene_modifier, scene_modifier_kwargs, reprojection_method)
#     388 scene_constructor_kwargs.update({
#     389     'vector_features': self.mapper_configs.feature.to_geoseries()
#     390 })
#     391 try:
#     392     # call scene constructor. The file-path (or URL) goes first
# --> 393     scene = scene_constructor.__call__(item.real_path, **scene_constructor_kwargs)
#     394     scene.scene_properties.sensing_time = item[self.time_column]
#     395 except Exception as e:
#
# File c:\Users\Julia\AppData\Local\Programs\Python\Python310\lib\site-packages\eodal\core\sensors\sentinel2.py:432, in Sentinel2.from_safe(cls, in_dir, band_selection, read_scl, apply_scaling, **kwargs)
#     430 # read band
#     431 try:
# --> 432     sentinel2.add_band(
#     433         Band.from_rasterio,
#     434         fpath_raster=band_fpath,
#     435         band_idx=1,
#     436         band_name_dst=band_name,
#     437         band_alias=color_name,
#     438         **kwargs,
#     439     )
#     440 except Exception as e:
#     441     raise Exception(
#     442         f"Could not add band {band_name} from {in_dir.name}: {e}"
#     443     )
#
# File c:\Users\Julia\AppData\Local\Programs\Python\Python310\lib\site-packages\eodal\core\raster.py:953, in RasterCollection.add_band(self, band_constructor, *args, **kwargs)
#     951         band = band_constructor
#     952     else:
# --> 953         band = band_constructor.__call__(*args, **kwargs)
#     954 except Exception as e:
#     955     raise ValueError(f"Cannot initialize new Band instance: {e}")
#
# File c:\Users\Julia\AppData\Local\Programs\Python\Python310\lib\site-packages\eodal\core\band.py:711, in Band.from_rasterio(cls, fpath_raster, band_idx, band_name_src, band_name_dst, vector_features, full_bounding_box_only, epsg_code, **kwargs)
#     709 if vector_features is not None:
#     710     masking = True
# --> 711     gdf_aoi = check_aoi_geoms(
#     712         in_dataset=vector_features,
#     713         fname_raster=_fpath_raster,
#     714         full_bounding_box_only=full_bounding_box_only,
#     715     )
#     716     # check for third dimension (has_z) and flatten it to 2d
#     717     gdf_aoi.geometry = convert_3D_2D(gdf_aoi.geometry)
#
# File c:\Users\Julia\AppData\Local\Programs\Python\Python310\lib\site-packages\eodal\utils\reprojection.py:131, in check_aoi_geoms(in_dataset, full_bounding_box_only, fname_raster, raster_crs)
#     129 sat_crs = None
#     130 if fname_raster is not None:
# --> 131     sat_crs = rio.open(fname_raster).crs
#     132 if raster_crs is not None and sat_crs is None:
#     133     sat_crs = raster_crs
#
# File c:\Users\Julia\AppData\Local\Programs\Python\Python310\lib\site-packages\rasterio\env.py:451, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     448     session = DummySession()
#     450 with env_ctor(session=session):
# --> 451     return f(*args, **kwds)
#
# File c:\Users\Julia\AppData\Local\Programs\Python\Python310\lib\site-packages\rasterio\__init__.py:321, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, **kwargs)
#     318 path = _parse_path(raw_dataset_path)
#     320 if mode == "r":
# --> 321     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     322 elif mode == "r+":
#     323     dataset = get_writer_for_path(path, driver=driver)(
#     324         path, mode, driver=driver, sharing=sharing, **kwargs
#     325     )
#
# File rasterio\_base.pyx:312, in rasterio._base.DatasetBase.__init__()
#
# File c:\Users\Julia\AppData\Local\Programs\Python\Python310\lib\site-packages\rasterio\_path.py:81, in _ParsedPath.name(self)
#      78     archive = parts.pop() if parts else None
#      79     return _ParsedPath(path, archive, scheme)
# ---> 81 @property
#      82 def name(self):
#      83     """The parsed path's original URI"""
#      84     if not self.scheme:
#
# KeyboardInterrupt:
